# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from pmdarima.arima import auto_arima
import statsmodels.api as sm 
from pylab import rcParams
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df = pd.read_csv('MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061378
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063570
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064667
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.063022
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061926
# ...          ...         ...         ...         ...         ...         ...
# 9029  2022-01-06  313.149994  318.700012  311.489990  313.880005  313.880005
# 9030  2022-01-07  314.149994  316.500000  310.089996  314.040009  314.040009
# 9031  2022-01-10  309.489990  314.720001  304.690002  314.269989  314.269989
# 9032  2022-01-11  313.380005  316.609985  309.890015  314.980011  314.980011
# 9033  2022-01-12  319.670013  323.410004  317.079987  318.269989  318.269989
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9029    39646100
# 9030    32674000
# 9031    44289500
# 9032    29386800
# 9033    34372200
#
# [9034 rows x 7 columns]

# %%
df['Close'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
df_close = df['Close']
df_close.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
def test_stationarity(timeseries):
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
test_stationarity(df_close)
# Out:
# Results of dickey fuller test
# Test Statistics                   9.500182
# p-value                           1.000000
# No. of lags used                 35.000000
# Number of observations used    8998.000000
# critical value (1%)              -3.431077
# critical value (5%)              -2.861861
# critical value (10%)             -2.566941
# dtype: float64

# %%
rcParams['figure.figsize'] = 10, 6
df_log = np.log(df_close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_data, test_data = df_log[3:int(len(df_log)*0.7)], df_log[int(len(df_log)*0.7):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
model_autoARIMA = auto_arima(train_data, test='adf', seasonal=False, trace=True,error_action='ignore',suppress_warnings=True, stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-39248.225, Time=0.64 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-39228.582, Time=0.33 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-39226.773, Time=0.21 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-39226.766, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-39218.005, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-39248.382, Time=1.97 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-39242.268, Time=1.00 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-39222.789, Time=0.28 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-39247.497, Time=0.50 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-39247.313, Time=1.38 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-39246.172, Time=0.86 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-39245.544, Time=0.57 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-39235.438, Time=0.36 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0] intercept
# Total fit time: 8.823 seconds

# %%
train_data, test_data = df[0:int(len(df)*0.7)], df[int(len(df)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = sm.tsa.arima.ARIMA(history, order=(1,1,2))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('Testing Mean Squared Error is {}'.format(MSE_error))
# Out:
# C:\Users\Jagos\miniconda3\envs\dsda\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Testing Mean Squared Error is 4.103290609607483

# %%
test_set_range = df[int(len(df)*0.7):].index
plt.plot(test_set_range, model_predictions, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('Microsoft Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.legend()
plt.show()
